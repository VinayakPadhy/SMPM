# %% [markdown]
# ## Importing The Libraries

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import GRU, Dense
from keras.models import Sequential
from keras.models import Model
from sklearn.metrics import mean_squared_error
import yfinance as yf
from datetime import date, timedelta, datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import time
import random

# %% [markdown]
# ## Importing DATASET

# %%
Stock_symbol = '^NSEI'
data = pd.read_csv('/content/Data 5 years - Sheet1.csv')
#data = yf.download(Stock_symbol, start='2013-01-01', end = '2022-12-31')

# %%
count_nan = data.isnull().sum()
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: Date           0
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# SMA20          0
# SMA50          0
# EMA20          0
# EMA50          0
# EMA200         0
# UpperBB        0
# LowerBB        0
# RSI            0
# MFI            0
# ATR            0
# Force_Index    0
# MACD           0
# MACD_SL        0
# ADX            0
# OBV            0
# OBV_EMA        0
# dtype: int64

# %% [markdown]
# # List of Features

# %%
data = data.loc[:, data.columns != 'Date']

FEATURES=data.columns.tolist()

print('FEATURE LIST')
print([f for f in FEATURES])

data = pd.DataFrame(data)
data_filtered = data[FEATURES]
print(data_filtered)
# Out:
# FEATURE LIST
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'SMA20', 'SMA50', 'EMA20', 'EMA50', 'EMA200', 'UpperBB', 'LowerBB', 'RSI', 'MFI', 'ATR', 'Force_Index', 'MACD', 'MACD_SL', 'ADX', 'OBV', 'OBV_EMA']
#              Open         High          Low        Close    Adj Close  Volume  \
# 0     10477.54980  10495.20020  10404.65039  10442.20020  10442.20020  153400
# 1     10482.65039  10503.59961  10429.54980  10443.20020  10443.20020  167300
# 2     10469.40039  10513.00000  10441.45020  10504.79980  10504.79980  174900
# 3     10534.25000  10566.09961  10520.09961  10558.84961  10558.84961  180900
# 4     10591.70020  10631.20020  10588.54980  10623.59961  10623.59961  169000
# ...           ...          ...          ...          ...          ...     ...
# 1227  17830.40039  18084.09961  17774.25000  18014.59961  18014.59961  176700
# 1228  18089.80078  18149.25000  17967.44922  18132.30078  18132.30078  214300
# 1229  18084.75000  18173.09961  18068.34961  18122.50000  18122.50000  193900
# 1230  18045.69922  18229.69922  17992.80078  18191.00000  18191.00000  281100
# 1231  18259.09961  18265.25000  18080.30078  18105.30078  18105.30078  192000
#
#             SMA20        SMA50        EMA20        EMA50  ...      LowerBB  \
# 0     10338.28257  10321.71500  10391.95908  10295.15271  ...  10065.99898
# 1     10354.05508  10326.88201  10396.83919  10300.95849  ...  10068.06503
# 2     10373.38257  10332.82400  10407.12115  10308.95227  ...  10067.10473
# 3     10399.12007  10338.09400  10421.57148  10318.75216  ...  10063.21136
# 4     10421.96504  10343.69000  10440.81225  10330.70697  ...  10055.41773
# ...           ...          ...          ...          ...  ...          ...
# 1227  18464.91006  18200.37496  18315.04121  18167.55115  ...  17972.16570
# 1228  18440.62256  18219.30699  18297.63736  18166.16878  ...  17950.26783
# 1229  18408.83008  18235.52098  18280.95761  18164.45628  ...  17928.05628
# 1230  18377.75508  18249.60199  18272.39022  18165.49721  ...  17916.73403
# 1231  18348.21514  18261.46301  18256.47694  18163.13657  ...  17898.81021
#
#             RSI        MFI         ATR   Force_Index       MACD    MACD_SL  \
# 0     55.795277  47.511587   97.721261 -1.357590e+07  65.926644  13.548731
# 1     55.861800  54.258031   96.160575  1.673000e+05  61.722033   7.475296
# 2     59.868178  61.290050   92.221261  1.077377e+07  62.638366   6.713303
# 3     63.038396  61.771720   85.896275  9.777610e+06  66.954128   8.823252
# 4     66.456883  60.517474   85.124930  1.094275e+07  74.737655  13.285424
# ...         ...        ...         ...           ...        ...        ...
# 1227  40.672810  33.651385  202.182199  3.671805e+07 -56.840691 -95.655350
# 1228  44.800308  41.134164  205.175084  2.522336e+07 -62.369159 -80.947054
# 1229  44.522543  40.837401  206.367885 -1.900371e+06 -66.771649 -68.279635
# 1230  46.996085  49.783779  205.103516  1.925535e+07 -63.995575 -52.402849
# 1231  44.332909  56.591949  205.753348 -1.645425e+07 -67.927700 -45.067979
#
#             ADX       OBV      OBV_EMA
# 0     15.715331  12111500  11957990.74
# 1     16.052246  12278800  11973267.37
# 2     16.225820  12453700  11996145.11
# 3     15.628212  12634600  12026547.73
# 4     14.766009  12803600  12063550.22
# ...         ...       ...          ...
# 1227  21.415301  56493000  56313190.35
# 1228  22.009546  56707300  56331957.48
# 1229  22.378551  56513400  56340597.60
# 1230  23.049166  56794500  56362212.00
# 1231  23.380467  56602500  56373654.29
#
# [1232 rows x 22 columns]

# %% [markdown]
# # Scaling the DATA

# %%
nrows = data_filtered.shape[0]
print(nrows)

np_data_unscaled = np.array(data_filtered)
np_data = np.reshape(np_data_unscaled, (nrows, -1))

scaler = MinMaxScaler()
np_data_scaled = scaler.fit_transform(np_data_unscaled)

# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_Close = pd.DataFrame(data_filtered['Close'])
np_Close_scaled = scaler_pred.fit_transform(df_Close)
data_filtered.head()
# Out:
# 1232
#           Open         High          Low        Close    Adj Close  Volume  \
# 0  10477.54980  10495.20020  10404.65039  10442.20020  10442.20020  153400
# 1  10482.65039  10503.59961  10429.54980  10443.20020  10443.20020  167300
# 2  10469.40039  10513.00000  10441.45020  10504.79980  10504.79980  174900
# 3  10534.25000  10566.09961  10520.09961  10558.84961  10558.84961  180900
# 4  10591.70020  10631.20020  10588.54980  10623.59961  10623.59961  169000
#
#          SMA20        SMA50        EMA20        EMA50  ...      LowerBB  \
# 0  10338.28257  10321.71500  10391.95908  10295.15271  ...  10065.99898
# 1  10354.05508  10326.88201  10396.83919  10300.95849  ...  10068.06503
# 2  10373.38257  10332.82400  10407.12115  10308.95227  ...  10067.10473
# 3  10399.12007  10338.09400  10421.57148  10318.75216  ...  10063.21136
# 4  10421.96504  10343.69000  10440.81225  10330.70697  ...  10055.41773
#
#          RSI        MFI        ATR   Force_Index       MACD    MACD_SL  \
# 0  55.795277  47.511587  97.721261 -1.357590e+07  65.926644  13.548731
# 1  55.861800  54.258031  96.160575  1.673000e+05  61.722033   7.475296
# 2  59.868178  61.290050  92.221261  1.077377e+07  62.638366   6.713303
# 3  63.038396  61.771720  85.896275  9.777610e+06  66.954128   8.823252
# 4  66.456883  60.517474  85.124930  1.094275e+07  74.737655  13.285424
#
#          ADX       OBV      OBV_EMA
# 0  15.715331  12111500  11957990.74
# 1  16.052246  12278800  11973267.37
# 2  16.225820  12453700  11996145.11
# 3  15.628212  12634600  12026547.73
# 4  14.766009  12803600  12063550.22
#
# [5 rows x 22 columns]

# %% [markdown]
# # Splitting The DATASET

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 50

# Prediction Index
prediction = "Close"
index_Close = data.columns.get_loc(prediction)

# Split the training data into train and train data sets
# As a first step, we get the number of rows to train the model on 80% of the data 
train_data_len = math.ceil(np_data_scaled.shape[0] * 0.8)

# Create the training and test data
train_data = np_data_scaled[0:train_data_len, :]
test_data = np_data_scaled[train_data_len - sequence_length:, :]

# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(sequence_length, data):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(sequence_length, data_len):
        x.append(data[i-sequence_length:i,:]) #contains sequence_length values 0-sequence_length * columsn
        y.append(data[i, index_Close]) #contains the prediction values for validation,  for single-step prediction
    
    # Convert the x and y to numpy arrays
    x = np.array(x)
    y = np.array(y)
    return x, y

# Generate training data and test data
X_train, Y_train = partition_dataset(sequence_length, train_data)
X_test, Y_test = partition_dataset(sequence_length, test_data)

psf = [0, 1, 2, 4, 6, 11, 17, 18, 20, 21]
X_train   = X_train[:,:,psf]
X_test   = X_test[:,:,psf]

# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)

# Validate that the prediction value and the input match up
# The last close price of the second input sample should equal the first prediction value
print(X_train[1][sequence_length-1][index_Close])
print(Y_train[0])
# Out:
# (936, 50, 10) (936,)
# (246, 50, 10) (246,)
# 0.23074832198888628
# 0.23074832198888628

# %% [markdown]
# # Error Rate

# %%
def error_rate(xtrain, ytrain, x, opts):
    # parameters
    fold = opts['fold']
    xt = fold['xt']
    yt = fold['yt']
    xv = fold['xv']
    yv = fold['yv']
    #print('#')
    #print(xt[:,:,x==1].shape)
    # number of instances
    num_train = np.size(xt, 0)
    num_valid = np.size(xv, 0)
    #print(num_train)

    # Define selected featur
    xtrain = xt[:,:,x == 1]
    #print(xtrain.shape)
    ytrain = yt.reshape(num_train)
    xtest = xv[:,:,x == 1]
    ytest = yv.reshape(num_valid)

    # Training
    model = Sequential()
    model.add(GRU(64, return_sequences=True, input_shape= (xtrain.shape[1],xtrain.shape[2])))
    model.add(GRU(64, return_sequences=False))
    model.add(Dense(1, activation='ReLU'))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mae'])
    model.fit(xtrain, ytrain, epochs = 10, batch_size = 32, verbose = 1)
    # Prediction
    ypred   = model.predict(xtest)
    error   = mean_squared_error(ytest, ypred, squared=False)
    
    return error

# %% [markdown]
# # Error Rate & Feature Size

# %%
def Fun(xtrain, ytrain, x, opts):
    # parameters
    alpha = 0.99
    beta = 1 - alpha
    # original feature size
    max_feat = len(x)
    #print(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    #print(num_feat)
    # Solve if no feature selected
    if num_feat == 0:
        cost = 1
    else:
        # Get error rate
        error = error_rate(xtrain, ytrain, x, opts)
        # Objective function
        cost = alpha * error + beta * (num_feat / max_feat)
        
    return cost

# %% [markdown]
# # Initilization Of Position

# %%
def init_position(lb, ub, N, dim):
    X = np.zeros([N, dim], dtype='float')
    for i in range(N):
        for d in range(dim):
            X[i,d] = lb[0,d] + (ub[0,d] - lb[0,d]) * np.random.rand()        
    
    return X

# %% [markdown]
# # Initilization Of Velocity

# %%
def init_velocity(lb, ub, N, dim):
    V    = np.zeros([N, dim], dtype='float')
    Vmax = np.zeros([1, dim], dtype='float')
    Vmin = np.zeros([1, dim], dtype='float')
    # Maximum & minimum velocity
    for d in range(dim):
        Vmax[0,d] = (ub[0,d] - lb[0,d]) / 2
        Vmin[0,d] = -Vmax[0,d]
        
    for i in range(N):
        for d in range(dim):
            V[i,d] = Vmin[0,d] + (Vmax[0,d] - Vmin[0,d]) * np.random.rand()  
        
    return V, Vmax, Vmin

# %% [markdown]
# # Binary Conversion

# %%
def binary_conversion(X, N, dim):
    Xbin = np.zeros([N, dim], dtype='int')
    
    thres = 0.5
    # For specifying Threshold value usin 1) tanh 2)  function (My Change)
    pos_avg =  np.average(X)
    #thres = (math.exp(pos_avg)-math.exp(-pos_avg))/(math.exp(pos_avg)+math.exp(-pos_avg));
    thres = 1 / (1 + math.exp(-pos_avg));
    print('\nThreshold Value:', thres, "\n")
    
    for i in range(N):
        for d in range(dim):
            if X[i,d] > thres:
                Xbin[i,d] = 1
            else:
                Xbin[i,d] = 0
    
    return Xbin

# %% [markdown]
# # Setting Boundry

# %%
def boundary(x, lb, ub):
    if x < lb:
        x = lb
    if x > ub:
        x = ub
    
    return x

# %% [markdown]
# # Algorithm

# %%
def jfs(xtrain, ytrain, opts):
    # Parameters
    ub    = 1
    lb    = 0
    w     = 0.9    # inertia weight
    c1    = 2      # acceleration factor
    c2    = 2      # acceleration factor
    
    N        = opts['N']
    max_iter = opts['T']
    if 'w' in opts:
        w    = opts['w']
    if 'c1' in opts:
        c1   = opts['c1']
    if 'c2' in opts:
        c2   = opts['c2'] 
    
    # Dimension
    dim = np.size(xtrain, 2)
    if np.size(lb) == 1:
        ub = ub * np.ones([1, dim], dtype='float')
        lb = lb * np.ones([1, dim], dtype='float')
    print(dim)
        
    # Initialize position & velocity
    X             = init_position(lb, ub, N, dim)
    #print(X)
    V, Vmax, Vmin = init_velocity(lb, ub, N, dim) 
    
    # Pre
    fit   = np.zeros([N, 1], dtype='float')
    Xgb   = np.zeros([1, dim], dtype='float')
    fitG  = float('inf')
    Xpb   = np.zeros([N, dim], dtype='float')
    fitP  = float('inf') * np.ones([N, 1], dtype='float')
    curve = np.zeros([1, max_iter], dtype='float') 
    t = 0
    
    while t < max_iter:
        print("For Iteration Number:", t+1, "\n")
        
        # Binary conversion
        Xbin = binary_conversion(X, N, dim)
        
        # Fitness
        for i in range(N):
            print("For Population Number", i+1, "\n")
            fit[i,0] = Fun(xtrain, ytrain, Xbin[i,:], opts)
            if fit[i,0] < fitP[i,0]:
                Xpb[i,:]  = X[i,:]
                fitP[i,0] = fit[i,0]
            if fitP[i,0] < fitG:
                Xgb[0,:]  = Xpb[i,:]
                fitG      = fitP[i,0]
        
        # Store result
        curve[0,t] = fitG.copy()
        print("\nIteration:", t + 1)
        print("Best (PSO):", curve[0,t], "\n")
        t += 1
        
        for i in range(N):
            for d in range(dim):
                # Update velocity
                r1     = np.random.rand()
                r2     = np.random.rand()
                V[i,d] = w * V[i,d] + c1 * r1 * (Xpb[i,d] - X[i,d]) + c2 * r2 * (Xgb[0,d] - X[i,d]) 
                # Boundary
                V[i,d] = boundary(V[i,d], Vmin[0,d], Vmax[0,d])
                # Update position
                X[i,d] = X[i,d] + V[i,d]
                # Boundary
                X[i,d] = boundary(X[i,d], lb[0,d], ub[0,d])
    
                
    # Best feature subset
    Gbin       = binary_conversion(Xgb, 1, dim) 
    Gbin       = Gbin.reshape(dim)
    pos        = np.asarray(range(0, dim))    
    sel_index  = pos[Gbin == 1]
    num_feat   = len(sel_index)
    # Create dictionary
    pso_data = {'sf': sel_index, 'c': curve, 'nf': num_feat}
    
    return pso_data

# %% [markdown]
# # Assigning Values

# %%
fold = {'xt':X_train, 'yt':Y_train, 'xv':X_test, 'yv':Y_test}

# %%
c1  = 2         # cognitive factor
c2  = 2         # social factor 
w   = 0.9       # inertia weight
k     = 5       # k-value in KNN
N     = 10       # number of population
T     = 10       # maximum number of iterations
opts = {'k':k, 'fold':fold, 'N':N, 'T':T, 'w':w, 'c1':c1, 'c2':c2}

# %% [markdown]
# # Feature Selection

# %%
# perform feature selection
start_time = time.time()
fmdl  = jfs(X_train, Y_train, opts)
print("Run Time --- %s seconds ---" % (time.time() - start_time))
sf    = fmdl['sf']
print(sf)
# Out:
# 10
# For Iteration Number: 1
#
#
# Threshold Value: 0.61336729367661
#
# For Population Number 1
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0147 - mae: 0.0855
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0019 - mae: 0.0274
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0199
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.7452e-04 - mae: 0.0155
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.9843e-04 - mae: 0.0138
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.6526e-04 - mae: 0.0133
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.3791e-04 - mae: 0.0129
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.1660e-04 - mae: 0.0126
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.0761e-04 - mae: 0.0124
# Epoch 10/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.0303e-04 - mae: 0.0125
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 2
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 3
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0264 - mae: 0.1107
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0315
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 8.0604e-04 - mae: 0.0195
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 7.0212e-04 - mae: 0.0180
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.3587e-04 - mae: 0.0172
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.6521e-04 - mae: 0.0161
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.0611e-04 - mae: 0.0153
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.5448e-04 - mae: 0.0147
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.1627e-04 - mae: 0.0141
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6166e-04 - mae: 0.0132
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 4
#
# Epoch 1/10
# 30/30 [==============================] - 4s 11ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0219 - mae: 0.1039
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0327
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0268
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0016 - mae: 0.0267
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0270
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0264
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0268
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0266
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0270
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0265
# 8/8 [==============================] - 1s 6ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 7
#
# Epoch 1/10
# 30/30 [==============================] - 6s 9ms/step - loss: 0.0216 - mae: 0.0992
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0018 - mae: 0.0316
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 7.8968e-04 - mae: 0.0201
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.8534e-04 - mae: 0.0160
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.9018e-04 - mae: 0.0143
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.7698e-04 - mae: 0.0141
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4951e-04 - mae: 0.0134
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4191e-04 - mae: 0.0132
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3728e-04 - mae: 0.0134
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.2814e-04 - mae: 0.0131
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 4s 11ms/step - loss: 0.0247 - mae: 0.1100
# Epoch 2/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0021 - mae: 0.0317
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0012 - mae: 0.0228
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 8.1998e-04 - mae: 0.0192
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.9888e-04 - mae: 0.0165
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.3240e-04 - mae: 0.0144
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6656e-04 - mae: 0.0135
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5774e-04 - mae: 0.0137
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.2320e-04 - mae: 0.0130
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.1587e-04 - mae: 0.0129
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 9
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0360 - mae: 0.1290
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0038 - mae: 0.0489
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0397
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0293
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.6426e-04 - mae: 0.0193
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.2778e-04 - mae: 0.0151
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.7307e-04 - mae: 0.0141
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5280e-04 - mae: 0.0138
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3477e-04 - mae: 0.0136
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6066e-04 - mae: 0.0141
# 8/8 [==============================] - 1s 3ms/step
# For Population Number 10
#
# Epoch 1/10
# 30/30 [==============================] - 5s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
#
# Iteration: 1
# Best (PSO): 0.021875937236441
#
# For Iteration Number: 2
#
#
# Threshold Value: 0.6038374369694787
#
# For Population Number 1
#
# For Population Number 2
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 3ms/step
# For Population Number 3
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0265 - mae: 0.1114
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0020 - mae: 0.0326
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0246
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 8.2050e-04 - mae: 0.0193
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.2330e-04 - mae: 0.0170
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.4058e-04 - mae: 0.0163
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.7899e-04 - mae: 0.0158
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.9337e-04 - mae: 0.0164
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.2612e-04 - mae: 0.0150
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.2263e-04 - mae: 0.0151
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 4
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0334 - mae: 0.1241
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0051 - mae: 0.0415
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0383
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0049 - mae: 0.0421
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0390
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0382
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0389
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0384
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0399
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0387
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 7
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 3ms/step
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0212 - mae: 0.1002
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0021 - mae: 0.0314
# Epoch 3/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0197
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 6.5846e-04 - mae: 0.0165
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.3547e-04 - mae: 0.0141
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.3971e-04 - mae: 0.0128
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.2643e-04 - mae: 0.0130
# Epoch 8/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.0514e-04 - mae: 0.0125
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 2.9296e-04 - mae: 0.0124
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 2.8079e-04 - mae: 0.0120
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 9
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0251 - mae: 0.1155
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0022 - mae: 0.0347
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0259
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 9.2157e-04 - mae: 0.0213
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 6.4481e-04 - mae: 0.0179
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 5.0766e-04 - mae: 0.0160
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.4207e-04 - mae: 0.0153
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.2397e-04 - mae: 0.0152
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.9829e-04 - mae: 0.0146
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.7031e-04 - mae: 0.0141
# 8/8 [==============================] - 1s 6ms/step
# For Population Number 10
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0209 - mae: 0.0978
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 7.8437e-04 - mae: 0.0213
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.2440e-04 - mae: 0.0146
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6863e-04 - mae: 0.0136
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5003e-04 - mae: 0.0133
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3828e-04 - mae: 0.0132
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.1713e-04 - mae: 0.0127
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0343e-04 - mae: 0.0126
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 2.9206e-04 - mae: 0.0123
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 2.9506e-04 - mae: 0.0124
# 8/8 [==============================] - 1s 3ms/step
#
# Iteration: 2
# Best (PSO): 0.021875937236441
#
# For Iteration Number: 3
#
#
# Threshold Value: 0.5907326462167016
#
# For Population Number 1
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.0196 - mae: 0.1004
# Epoch 2/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0041 - mae: 0.0439
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0037 - mae: 0.0418
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0037 - mae: 0.0413
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0037 - mae: 0.0397
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0036 - mae: 0.0383
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0036 - mae: 0.0391
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0036 - mae: 0.0379
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0036 - mae: 0.0386
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0038 - mae: 0.0408
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 2
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0796 - mae: 0.2019
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0409
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0283
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0245
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 9.0327e-04 - mae: 0.0206
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.0376e-04 - mae: 0.0168
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.3618e-04 - mae: 0.0145
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5994e-04 - mae: 0.0133
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3866e-04 - mae: 0.0130
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.2396e-04 - mae: 0.0128
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 3
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0215 - mae: 0.0991
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0012 - mae: 0.0261
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.9348e-04 - mae: 0.0142
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6626e-04 - mae: 0.0137
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5170e-04 - mae: 0.0133
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4709e-04 - mae: 0.0134
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5439e-04 - mae: 0.0137
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3009e-04 - mae: 0.0131
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.1485e-04 - mae: 0.0128
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 2.9209e-04 - mae: 0.0122
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 4
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0209 - mae: 0.0990
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0018 - mae: 0.0287
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 9.2508e-04 - mae: 0.0202
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.5833e-04 - mae: 0.0171
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.0983e-04 - mae: 0.0157
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.9755e-04 - mae: 0.0158
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.4599e-04 - mae: 0.0153
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.3896e-04 - mae: 0.0150
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.3274e-04 - mae: 0.0151
# Epoch 10/10
# 30/30 [==============================] - 0s 11ms/step - loss: 3.9858e-04 - mae: 0.0143
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0244 - mae: 0.1053
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0344
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0244
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 5.9306e-04 - mae: 0.0177
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.9710e-04 - mae: 0.0138
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.8683e-04 - mae: 0.0140
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5867e-04 - mae: 0.0135
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.4028e-04 - mae: 0.0130
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.2436e-04 - mae: 0.0127
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3576e-04 - mae: 0.0131
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 7
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0359 - mae: 0.1311
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0346
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0259
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 7.8500e-04 - mae: 0.0198
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.7142e-04 - mae: 0.0151
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.7009e-04 - mae: 0.0135
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4264e-04 - mae: 0.0130
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.2643e-04 - mae: 0.0127
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.1654e-04 - mae: 0.0125
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.0709e-04 - mae: 0.0125
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0185 - mae: 0.0946
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0019 - mae: 0.0285
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 8.6795e-04 - mae: 0.0185
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.8462e-04 - mae: 0.0146
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.6653e-04 - mae: 0.0136
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.7691e-04 - mae: 0.0140
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.2435e-04 - mae: 0.0129
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0260e-04 - mae: 0.0124
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3488e-04 - mae: 0.0131
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 2.8583e-04 - mae: 0.0120
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 9
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.0316 - mae: 0.1237
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0053 - mae: 0.0413
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0049 - mae: 0.0401
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0050 - mae: 0.0397
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0048 - mae: 0.0396
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0047 - mae: 0.0390
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0047 - mae: 0.0387
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0399
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0386
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0046 - mae: 0.0383
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 10
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0293 - mae: 0.1147
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0015 - mae: 0.0272
# Epoch 3/10
# 30/30 [==============================] - 0s 10ms/step - loss: 8.5874e-04 - mae: 0.0205
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 5.8960e-04 - mae: 0.0166
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.5272e-04 - mae: 0.0148
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.8214e-04 - mae: 0.0138
# Epoch 7/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.5736e-04 - mae: 0.0135
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.5443e-04 - mae: 0.0137
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.3343e-04 - mae: 0.0132
# Epoch 10/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.1894e-04 - mae: 0.0130
# 8/8 [==============================] - 1s 5ms/step
#
# Iteration: 3
# Best (PSO): 0.021875937236441
#
# For Iteration Number: 4
#
#
# Threshold Value: 0.5977519699197439
#
# For Population Number 1
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 2
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 3
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0164 - mae: 0.0906
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0010 - mae: 0.0245
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.2514e-04 - mae: 0.0150
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.9251e-04 - mae: 0.0142
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6594e-04 - mae: 0.0136
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5777e-04 - mae: 0.0136
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5256e-04 - mae: 0.0135
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5146e-04 - mae: 0.0134
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.2483e-04 - mae: 0.0131
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.2503e-04 - mae: 0.0130
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 4
#
# Epoch 1/10
# 30/30 [==============================] - 5s 9ms/step - loss: 0.0213 - mae: 0.0982
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0016 - mae: 0.0277
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 8.6127e-04 - mae: 0.0191
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 6.3235e-04 - mae: 0.0168
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.8873e-04 - mae: 0.0152
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.0631e-04 - mae: 0.0143
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.8050e-04 - mae: 0.0139
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6665e-04 - mae: 0.0138
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.5986e-04 - mae: 0.0137
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.6226e-04 - mae: 0.0139
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0122 - mae: 0.0793
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0014 - mae: 0.0276
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.0020e-04 - mae: 0.0174
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.0150e-04 - mae: 0.0140
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.6053e-04 - mae: 0.0134
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5399e-04 - mae: 0.0133
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3788e-04 - mae: 0.0129
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.2173e-04 - mae: 0.0126
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.1187e-04 - mae: 0.0124
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.0615e-04 - mae: 0.0125
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0283 - mae: 0.1066
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0012 - mae: 0.0249
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 5.8199e-04 - mae: 0.0163
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.5834e-04 - mae: 0.0146
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.7190e-04 - mae: 0.0132
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3414e-04 - mae: 0.0128
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0738e-04 - mae: 0.0126
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0747e-04 - mae: 0.0125
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 2.9135e-04 - mae: 0.0122
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 2.8115e-04 - mae: 0.0120
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 7
#
# Epoch 1/10
# 30/30 [==============================] - 4s 11ms/step - loss: 0.0142 - mae: 0.0825
# Epoch 2/10
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0225
# Epoch 3/10
# 30/30 [==============================] - 0s 11ms/step - loss: 5.9281e-04 - mae: 0.0162
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.6562e-04 - mae: 0.0147
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.1325e-04 - mae: 0.0144
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.8053e-04 - mae: 0.0139
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.5790e-04 - mae: 0.0134
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.6987e-04 - mae: 0.0141
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5074e-04 - mae: 0.0135
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.1822e-04 - mae: 0.0127
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0211 - mae: 0.0960
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0297
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0014 - mae: 0.0232
# Epoch 4/10
# 30/30 [==============================] - 0s 7ms/step - loss: 8.3840e-04 - mae: 0.0184
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 5.6239e-04 - mae: 0.0158
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.1313e-04 - mae: 0.0140
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.7366e-04 - mae: 0.0134
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4362e-04 - mae: 0.0130
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5314e-04 - mae: 0.0133
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.4809e-04 - mae: 0.0135
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 9
#
# Epoch 1/10
# 30/30 [==============================] - 5s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 3ms/step
# For Population Number 10
#
# Epoch 1/10
# 30/30 [==============================] - 4s 11ms/step - loss: 0.0173 - mae: 0.0926
# Epoch 2/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0237
# Epoch 3/10
# 30/30 [==============================] - 0s 10ms/step - loss: 5.6421e-04 - mae: 0.0157
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.0892e-04 - mae: 0.0138
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.5213e-04 - mae: 0.0131
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.4026e-04 - mae: 0.0133
# Epoch 7/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.0639e-04 - mae: 0.0125
# Epoch 8/10
# 30/30 [==============================] - 0s 10ms/step - loss: 2.9179e-04 - mae: 0.0122
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 2.8849e-04 - mae: 0.0122
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 2.8703e-04 - mae: 0.0121
# 8/8 [==============================] - 1s 4ms/step
#
# Iteration: 4
# Best (PSO): 0.021875937236441
#
# For Iteration Number: 5
#
#
# Threshold Value: 0.5986657797289052
#
# For Population Number 1
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0184 - mae: 0.0928
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0023 - mae: 0.0332
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0258
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 9.4619e-04 - mae: 0.0208
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.3081e-04 - mae: 0.0172
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.3558e-04 - mae: 0.0143
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.6780e-04 - mae: 0.0135
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.4020e-04 - mae: 0.0130
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3276e-04 - mae: 0.0131
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0511e-04 - mae: 0.0124
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 2
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0207 - mae: 0.1001
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 9.5401e-04 - mae: 0.0226
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5782e-04 - mae: 0.0135
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.4110e-04 - mae: 0.0131
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.2534e-04 - mae: 0.0129
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.1677e-04 - mae: 0.0125
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0383e-04 - mae: 0.0124
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 2.9304e-04 - mae: 0.0121
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 2.8496e-04 - mae: 0.0120
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 2.8061e-04 - mae: 0.0120
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 3
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 4
#
# Epoch 1/10
# 30/30 [==============================] - 5s 11ms/step - loss: 0.0159 - mae: 0.0878
# Epoch 2/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0018 - mae: 0.0292
# Epoch 3/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0010 - mae: 0.0219
# Epoch 4/10
# 30/30 [==============================] - 0s 11ms/step - loss: 7.4176e-04 - mae: 0.0182
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 5.4570e-04 - mae: 0.0156
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.2534e-04 - mae: 0.0142
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.6498e-04 - mae: 0.0135
# Epoch 8/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.5210e-04 - mae: 0.0133
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.1362e-04 - mae: 0.0127
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0849e-04 - mae: 0.0127
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0225 - mae: 0.1018
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0020 - mae: 0.0295
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0012 - mae: 0.0229
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 7.4627e-04 - mae: 0.0177
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.7314e-04 - mae: 0.0148
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.4599e-04 - mae: 0.0150
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.0018e-04 - mae: 0.0143
# Epoch 8/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.0646e-04 - mae: 0.0148
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.6378e-04 - mae: 0.0140
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3151e-04 - mae: 0.0130
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0214 - mae: 0.1001
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0015 - mae: 0.0280
# Epoch 3/10
# 30/30 [==============================] - 0s 7ms/step - loss: 7.0693e-04 - mae: 0.0177
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 5.2060e-04 - mae: 0.0152
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.1558e-04 - mae: 0.0140
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5676e-04 - mae: 0.0131
# Epoch 7/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.3489e-04 - mae: 0.0130
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.1605e-04 - mae: 0.0127
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.0716e-04 - mae: 0.0125
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 2.8902e-04 - mae: 0.0122
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 7
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0269 - mae: 0.1078
# Epoch 2/10
# ...
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 4s 13ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 7
#
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 9
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.0287 - mae: 0.1263
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0066 - mae: 0.0635
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0062 - mae: 0.0635
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0063 - mae: 0.0631
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0062 - mae: 0.0649
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0059 - mae: 0.0620
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0059 - mae: 0.0623
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0060 - mae: 0.0627
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0058 - mae: 0.0618
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0058 - mae: 0.0599
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 10
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
#
# Iteration: 9
# Best (PSO): 0.021814291703756247
#
# For Iteration Number: 10
#
#
# Threshold Value: 0.5964918998472595
#
# For Population Number 1
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0225 - mae: 0.1040
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0017 - mae: 0.0291
# Epoch 3/10
# 30/30 [==============================] - 0s 10ms/step - loss: 8.2149e-04 - mae: 0.0185
# Epoch 4/10
# 30/30 [==============================] - 0s 12ms/step - loss: 5.3903e-04 - mae: 0.0155
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 4.1034e-04 - mae: 0.0138
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.3364e-04 - mae: 0.0128
# Epoch 7/10
# 30/30 [==============================] - 0s 11ms/step - loss: 3.0740e-04 - mae: 0.0124
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.0369e-04 - mae: 0.0125
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.0060e-04 - mae: 0.0125
# Epoch 10/10
# 30/30 [==============================] - 0s 10ms/step - loss: 2.9995e-04 - mae: 0.0125
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 2
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.0202 - mae: 0.0974
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0011 - mae: 0.0238
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.1522e-04 - mae: 0.0146
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.8291e-04 - mae: 0.0138
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.8215e-04 - mae: 0.0138
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5583e-04 - mae: 0.0134
# Epoch 7/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.4204e-04 - mae: 0.0130
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.4057e-04 - mae: 0.0131
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3727e-04 - mae: 0.0130
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.0912e-04 - mae: 0.0125
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 3
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0207 - mae: 0.0997
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0018 - mae: 0.0291
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 9.4653e-04 - mae: 0.0204
# Epoch 4/10
# 30/30 [==============================] - 0s 9ms/step - loss: 6.9901e-04 - mae: 0.0173
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 5.4561e-04 - mae: 0.0160
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.3476e-04 - mae: 0.0144
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.8844e-04 - mae: 0.0138
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5999e-04 - mae: 0.0134
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.5421e-04 - mae: 0.0136
# Epoch 10/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3986e-04 - mae: 0.0131
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 4
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 5
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0252 - mae: 0.1081
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0021 - mae: 0.0344
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0011 - mae: 0.0254
# Epoch 4/10
# 30/30 [==============================] - 0s 9ms/step - loss: 6.7384e-04 - mae: 0.0189
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 4.3845e-04 - mae: 0.0150
# Epoch 6/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.8695e-04 - mae: 0.0138
# Epoch 7/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.6801e-04 - mae: 0.0137
# Epoch 8/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.4337e-04 - mae: 0.0130
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.4945e-04 - mae: 0.0133
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.3791e-04 - mae: 0.0131
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 6
#
# Epoch 1/10
# 30/30 [==============================] - 4s 9ms/step - loss: 0.0211 - mae: 0.0997
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0023 - mae: 0.0323
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0011 - mae: 0.0218
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 6.2682e-04 - mae: 0.0164
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 4.5587e-04 - mae: 0.0148
# Epoch 6/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.6138e-04 - mae: 0.0132
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.4683e-04 - mae: 0.0132
# Epoch 8/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.4469e-04 - mae: 0.0132
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.0951e-04 - mae: 0.0125
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 2.9880e-04 - mae: 0.0124
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 7
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.0235 - mae: 0.1057
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0310
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0011 - mae: 0.0209
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 6.7934e-04 - mae: 0.0165
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 4.7599e-04 - mae: 0.0144
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.8839e-04 - mae: 0.0136
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.7056e-04 - mae: 0.0137
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3927e-04 - mae: 0.0128
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.2103e-04 - mae: 0.0127
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.2358e-04 - mae: 0.0130
# 8/8 [==============================] - 1s 4ms/step
# For Population Number 8
#
# Epoch 1/10
# 30/30 [==============================] - 5s 10ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 2/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 4/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 6/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2332 - mae: 0.4325
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2332 - mae: 0.4325
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 9
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0196 - mae: 0.0973
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0339
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 9.9092e-04 - mae: 0.0218
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 6.0770e-04 - mae: 0.0171
# Epoch 5/10
# 30/30 [==============================] - 0s 9ms/step - loss: 4.6053e-04 - mae: 0.0153
# Epoch 6/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.8906e-04 - mae: 0.0142
# Epoch 7/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.7423e-04 - mae: 0.0139
# Epoch 8/10
# 30/30 [==============================] - 0s 11ms/step - loss: 3.6608e-04 - mae: 0.0139
# Epoch 9/10
# 30/30 [==============================] - 0s 10ms/step - loss: 4.3072e-04 - mae: 0.0153
# Epoch 10/10
# 30/30 [==============================] - 0s 10ms/step - loss: 3.6663e-04 - mae: 0.0140
# 8/8 [==============================] - 1s 5ms/step
# For Population Number 10
#
# Epoch 1/10
# 30/30 [==============================] - 4s 10ms/step - loss: 0.0164 - mae: 0.0890
# Epoch 2/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0307
# Epoch 3/10
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0013 - mae: 0.0233
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 8.7942e-04 - mae: 0.0190
# Epoch 5/10
# 30/30 [==============================] - 0s 8ms/step - loss: 5.9778e-04 - mae: 0.0161
# Epoch 6/10
# 30/30 [==============================] - 0s 9ms/step - loss: 4.2157e-04 - mae: 0.0139
# Epoch 7/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.7780e-04 - mae: 0.0136
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3134e-04 - mae: 0.0128
# Epoch 9/10
# 30/30 [==============================] - 0s 9ms/step - loss: 3.0708e-04 - mae: 0.0124
# Epoch 10/10
# 30/30 [==============================] - 0s 9ms/step - loss: 2.9936e-04 - mae: 0.0121
# 8/8 [==============================] - 1s 4ms/step
#
# Iteration: 10
# Best (PSO): 0.02143512633258463
#
#
# Threshold Value: 0.5923268572539733
#
# Run Time --- 856.0295679569244 seconds ---
# [3 5]

# %%
# plot convergence
curve   = fmdl['c']
curve   = curve.reshape(np.size(curve,1))
x       = np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, curve, 'o-')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('Fitness')
ax.set_title('PSO')
ax.grid()
plt.show()

# %%
# number of selected features
num_feat = fmdl['nf']
print("Feature Size:", num_feat)

#Selected Features
print('FEATURE LIST:')
for i in sf:
    print(FEATURES[i], end=', ')
# Out:
# Feature Size: 2
# FEATURE LIST:
# Close, Volume,

# %% [markdown]
# # Making Prediction with Selected Features

# %%
# model with selected features
num_train = np.size(X_train, 0)
num_valid = np.size(X_test, 0)
print(X_train.shape)
X_train   = X_train[:,:,sf]
print(X_train.shape)
Y_train   = Y_train.reshape(num_train)  # Solve bug
X_test   = X_test[:,:,sf]
Y_test   = Y_test.reshape(num_valid) 

model = Sequential()
model.add(GRU(64, return_sequences=True, input_shape= (X_train.shape[1],X_train.shape[2])))
model.add(GRU(64, return_sequences=False))
model.add(Dense(1, activation='ReLU'))
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mae'])
model.fit(X_train, Y_train, epochs = 10, batch_size = 32, verbose = 1)

# accuracy
y_pred    = model.predict(X_test)
RMSE       = mean_squared_error(Y_test, y_pred, squared=False)
print("RMSE:", RMSE)

accuracy = r2_score(Y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# (936, 50, 10)
# (936, 50, 2)
# Epoch 1/10
# 30/30 [==============================] - 4s 8ms/step - loss: 0.0309 - mae: 0.1167
# Epoch 2/10
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0325
# Epoch 3/10
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0013 - mae: 0.0233
# Epoch 4/10
# 30/30 [==============================] - 0s 8ms/step - loss: 9.0760e-04 - mae: 0.0188
# Epoch 5/10
# 30/30 [==============================] - 0s 7ms/step - loss: 6.2751e-04 - mae: 0.0164
# Epoch 6/10
# 30/30 [==============================] - 0s 7ms/step - loss: 4.4851e-04 - mae: 0.0142
# Epoch 7/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.7270e-04 - mae: 0.0134
# Epoch 8/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.4178e-04 - mae: 0.0131
# Epoch 9/10
# 30/30 [==============================] - 0s 8ms/step - loss: 3.3287e-04 - mae: 0.0130
# Epoch 10/10
# 30/30 [==============================] - 0s 7ms/step - loss: 3.2649e-04 - mae: 0.0129
# 8/8 [==============================] - 1s 4ms/step
# RMSE: 0.0211393091100632
# Accuracy: 0.919682038145316

# %% [markdown]
# # Graphical Representation

# %%
scaler.inverse_transform(np_data)
scaler_pred.inverse_transform(y_pred)

plt.plot(Y_test.reshape(-1, 1), label='Actual Values')
plt.plot(y_pred.reshape(-1, 1), label='Predictions')
plt.legend()
plt.show()
